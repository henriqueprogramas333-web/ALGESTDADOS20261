# %% [markdown]
# <a href="https://colab.research.google.com/github/henriqueprogramas333-web/ALGESTDADOS20261/blob/main/Teste/2026_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("O Galo da Massa é o time da virada")
# Out:
# O Galo da Massa é o time da virada

# %%
print("As Maria não aguenta")
# Out:
# As Maria não aguenta
